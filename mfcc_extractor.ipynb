# %%
import os
import numpy as np
print("numpy version: ", np.__version__)
import matplotlib.pyplot as plt
import librosa
import audiofile as af
import json
import soundfile as sf
import pandas as pd
# Out:
# numpy version:  1.26.4

# %%
# go into each json file in the directory and extract the data into a df and create rows with each label at event level with id the id of the subject

# get the list of json files
def read_json_files(directory):
    json_files = [f for f in os.listdir(directory) if f.endswith('.json')]

    list_of_dicts = []
    

    # Loop through each JSON file and load its content into the dictionary
    for json_file in json_files:
        file_path = os.path.join(directory, json_file)
        with open(file_path, 'r', encoding='utf-8') as f:
            data_dict = {}
            data = json.load(f)
            data_dict[json_file] = data
            list_of_dicts.append(data_dict)

    return json_files,data_dict,list_of_dicts

def gender_transform(gender):
    if gender=='0':
        gender = 'Male'
    else:
        gender = 'Female'
    return gender

def location_transform(location):
    if location =='p1':
        return 'left posterior'
    elif location =='p2':
        return 'left lateral'
    elif location =='p3':
        return 'right posterior'
    else:
        return 'right lateral'
    
def record_level_df_create(list):

    # List to collect rows for DataFrame
    rows = []

    # Access and print the 'record_annotation' for each dictionary in the list
    for dictionary in list:
        for file_name, data in dictionary.items():
            parts = file_name.split('_')
            # Add a row with the filename and record_annotation
            rows.append({
                # the patient number is the file name until the first _
                'recording_number':parts[4].split('.')[0],
                'patient_number': parts[0],
                'age':float(parts[1]),
                'gender':gender_transform(parts[2]),
                'recording_location':location_transform(parts[3]),
                'record_annotation': data.get('record_annotation', 'N/A')
            })

    record_level_df = pd.DataFrame(rows)
    record_level_df.set_index('recording_number', inplace=True)
    return record_level_df


def event_level_df_create(list):

    # List to collect rows for DataFrame
    rows = []
    # Access and print the 'record_annotation' for each dictionary in the list
    for dictionary in list:
        for file_name, data in dictionary.items():
            parts = file_name.split('_')
            # Add a row with the filename and record_annotation
            if not data.get('event_annotation', []):
                rows.append({
                    # the patient number is the file name until the first _
                    'recording_number':parts[4].split('.')[0],
                    'patient_number': parts[0],
                    'age':float(parts[1]),
                    'gender':gender_transform(parts[2]),
                    'recording_location':location_transform(parts[3]),
                    'start': 'N/A',
                    'end': 'N/A',
                    'event_annotation': data.get('event_annotation', 'N/A')
                })
            else:
                for event in data.get('event_annotation', []):
                    rows.append({
                        # the patient number is the file name until the first _
                        'recording_number':parts[4].split('.')[0],
                        'patient_number': parts[0],
                        'age':float(parts[1]),
                        'gender':gender_transform(parts[2]),
                        'recording_location':location_transform(parts[3]),
                        'start': event.get('start', 'N/A'),
                        'end': event.get('end', 'N/A'),
                        'event_annotation': event.get('type', 'N/A'),
                    })

    event_level_df = pd.DataFrame(rows)
    event_level_df.set_index('recording_number', inplace=True)

    return event_level_df

# %%
# Specify your directory here
directory_path = 'train_classification_json'
_,_,train_json_list = read_json_files(directory_path)

# %%
train_record_level_df = record_level_df_create(train_json_list)
# count the number of males and females
print(train_record_level_df['record_annotation'].value_counts())

train_record_level_df
# Out:
# record_annotation
# Normal          1303
# DAS              248
# Poor Quality     177
# CAS              126
# CAS & DAS         95
# Name: count, dtype: int64
#                  patient_number   age  gender recording_location  \
# recording_number
# 1340                   42272778   7.5    Male     left posterior
# 2306                   41166273   3.9    Male    right posterior
# 2178                   41275381   2.6    Male      right lateral
# 3326                   65091224   2.9    Male      right lateral
# 2410                   65091359  10.4    Male       left lateral
# ...                         ...   ...     ...                ...
# 2754                   41267024   0.3    Male      right lateral
# 245                    41260684   3.8  Female     left posterior
# 2022                   41074892  10.0  Female       left lateral
# 3115                   41161556   1.7    Male     left posterior
# 97                     41112999   3.2    Male     left posterior
#
#                  record_annotation
# recording_number
# 1340                        Normal
# 2306                        Normal
# 2178                        Normal
# 3326                        Normal
# 2410                        Normal
# ...                            ...
# 2754                        Normal
# 245                         Normal
# 2022                        Normal
# 3115                           DAS
# 97                          Normal
#
# [1949 rows x 5 columns]

# %%
train_event_level_df = event_level_df_create(train_json_list)
print(train_event_level_df['event_annotation'].value_counts())
train_event_level_df
# Out:
# event_annotation
# Normal            5159
# Fine Crackle       912
# Wheeze             452
# []                 177
# Coarse Crackle      49
# Rhonchi             39
# Wheeze+Crackle      30
# Stridor             15
# Name: count, dtype: int64
#                  patient_number  age gender recording_location start   end  \
# recording_number
# 1340                   42272778  7.5   Male     left posterior  6422  7457
# 1340                   42272778  7.5   Male     left posterior  8436  9169
# 1340                   42272778  7.5   Male     left posterior  4409  5786
# 1340                   42272778  7.5   Male     left posterior    79  4164
# 2306                   41166273  3.9   Male    right posterior   796  2069
# ...                         ...  ...    ...                ...   ...   ...
# 3115                   41161556  1.7   Male     left posterior  6672  7176
# 3115                   41161556  1.7   Male     left posterior  7991  8615
# 97                     41112999  3.2   Male     left posterior  3776  5043
# 97                     41112999  3.2   Male     left posterior  6456  7488
# 97                     41112999  3.2   Male     left posterior   993  3487
#
#                  event_annotation
# recording_number
# 1340                       Normal
# 1340                       Normal
# 1340                       Normal
# 1340                       Normal
# 2306                       Normal
# ...                           ...
# 3115                 Fine Crackle
# 3115                 Fine Crackle
# 97                         Normal
# 97                         Normal
# 97                         Normal
#
# [6833 rows x 7 columns]

# %%
# Specify your directory here
directory_path = 'test_classification_json/2022/inter_test_json'
_,_,inter_test_json_list = read_json_files(directory_path)
inter_test_record_level_df = record_level_df_create(inter_test_json_list)
print(inter_test_record_level_df['record_annotation'].value_counts())
inter_test_record_level_df
# Out:
# record_annotation
# Normal          241
# CAS              65
# DAS              24
# CAS & DAS        17
# Poor Quality      8
# Name: count, dtype: int64
#                  patient_number  age  gender recording_location  \
# recording_number
# 4147                   41209060  4.4  Female    right posterior
# 3576                   65109516  0.2    Male    right posterior
# 3579                   64714172  3.6  Female      right lateral
# 4166                   65118898  0.7    Male      right lateral
# 3581                   64714172  3.6  Female       left lateral
# ...                         ...  ...     ...                ...
# 4110                   65121853  1.5    Male      right lateral
# 1146                   40888395  3.4    Male     left posterior
# 3624                   65071184  4.8    Male       left lateral
# 3664                   65109516  0.2    Male      right lateral
# 4207                   41225759  7.2  Female     left posterior
#
#                  record_annotation
# recording_number
# 4147                        Normal
# 3576                           DAS
# 3579                        Normal
# 4166                           CAS
# 3581                        Normal
# ...                            ...
# 4110                           DAS
# 1146                        Normal
# 3624                        Normal
# 3664                        Normal
# 4207                        Normal
#
# [355 rows x 5 columns]

# %%
inter_test_event_level_df = event_level_df_create(inter_test_json_list)
print(inter_test_event_level_df['event_annotation'].value_counts())
inter_test_event_level_df
# Out:
# event_annotation
# Normal            1040
# Wheeze             305
# Fine Crackle        80
# []                   8
# Coarse Crackle       3
# Wheeze+Crackle       1
# Name: count, dtype: int64
#                  patient_number  age  gender recording_location  start    end  \
# recording_number
# 4147                   41209060  4.4  Female    right posterior     81   2532
# 4147                   41209060  4.4  Female    right posterior   4773   6877
# 4147                   41209060  4.4  Female    right posterior   6934   9383
# 4147                   41209060  4.4  Female    right posterior   9426  11178
# 4147                   41209060  4.4  Female    right posterior  11254  13551
# ...                         ...  ...     ...                ...    ...    ...
# 1146                   40888395  3.4    Male     left posterior   8025   8803
# 3624                   65071184  4.8    Male       left lateral   2637   4916
# 3664                   65109516  0.2    Male      right lateral   2059   3319
# 4207                   41225759  7.2  Female     left posterior  13677  15186
# 4207                   41225759  7.2  Female     left posterior    124   3907
#
#                  event_annotation
# recording_number
# 4147                       Normal
# 4147                       Normal
# 4147                       Normal
# 4147                       Normal
# 4147                       Normal
# ...                           ...
# 1146                       Normal
# 3624                       Normal
# 3664                       Normal
# 4207                       Normal
# 4207                       Normal
#
# [1437 rows x 7 columns]

# %%
# Specify your directory here
directory_path = 'test_classification_json/2022/intra_test_json'
_,_,intra_test_json_list = read_json_files(directory_path)
intra_test_record_level_df = record_level_df_create(intra_test_json_list)
print(intra_test_record_level_df['record_annotation'].value_counts())
intra_test_record_level_df
# Out:
# record_annotation
# Normal          241
# DAS              75
# CAS              42
# CAS & DAS        19
# Poor Quality      2
# Name: count, dtype: int64
#                  patient_number   age  gender recording_location  \
# recording_number
# 2793                   65045423   5.2  Female      right lateral
# 2915                   41281333   0.2  Female       left lateral
# 1280                   63613821   9.2  Female       left lateral
# 2927                   41279835  14.1    Male       left lateral
# 190                    41159145   3.3    Male       left lateral
# ...                         ...   ...     ...                ...
# 260                    65044049   0.9  Female      right lateral
# 2624                   64743918   7.0    Male    right posterior
# 1095                   65064302   3.2  Female    right posterior
# 1268                   65066754   9.0    Male    right posterior
# 898                    40801342   4.0  Female       left lateral
#
#                  record_annotation
# recording_number
# 2793                           DAS
# 2915                     CAS & DAS
# 1280                           DAS
# 2927                           DAS
# 190                         Normal
# ...                            ...
# 260                            DAS
# 2624                           CAS
# 1095                        Normal
# 1268                        Normal
# 898                            DAS
#
# [379 rows x 5 columns]

# %%
intra_test_event_level_df = event_level_df_create(intra_test_json_list)
print(intra_test_event_level_df['event_annotation'].value_counts())
intra_test_event_level_df
# Out:
# event_annotation
# Normal            688
# Fine Crackle      175
# Wheeze            108
# Coarse Crackle     14
# Rhonchi            14
# Wheeze+Crackle      3
# Stridor             2
# []                  2
# Name: count, dtype: int64
#                  patient_number  age  gender recording_location start   end  \
# recording_number
# 2793                   65045423  5.2  Female      right lateral  5547  6020
# 2793                   65045423  5.2  Female      right lateral  6842  7464
# 2793                   65045423  5.2  Female      right lateral  3578  4531
# 2915                   41281333  0.2  Female       left lateral  7269  7686
# 2915                   41281333  0.2  Female       left lateral  7755  8400
# ...                         ...  ...     ...                ...   ...   ...
# 898                    40801342  4.0  Female       left lateral  3463  4239
# 898                    40801342  4.0  Female       left lateral  6101  6957
# 898                    40801342  4.0  Female       left lateral  2108  2830
# 898                    40801342  4.0  Female       left lateral  4918  5575
# 898                    40801342  4.0  Female       left lateral  7736  8279
#
#                  event_annotation
# recording_number
# 2793               Coarse Crackle
# 2793               Coarse Crackle
# 2793               Coarse Crackle
# 2915                       Wheeze
# 2915                 Fine Crackle
# ...                           ...
# 898                  Fine Crackle
# 898                  Fine Crackle
# 898                  Fine Crackle
# 898                  Fine Crackle
# 898                  Fine Crackle
#
# [1006 rows x 7 columns]

# %%
def get_appropriate_n_fft(signal_length):
            return 2**int(np.floor(np.log2(signal_length)))

def extract_mfccs(wav_files, n_mfcc=13):
    mfccs_dict = {}
    
    for wav_file in wav_files:
        # Load the audio file
        y, sr = librosa.load(wav_file, sr=4000)
        

        n_fft = get_appropriate_n_fft(len(y))
        # Compute MFCCs
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc,n_fft=n_fft)
        
        # Store the MFCCs in the dictionary
        mfccs_dict[wav_file] = mfccs
    
    return mfccs_dict

train_wav_list = [os.path.join('splitted_training', f) for f in os.listdir('splitted_training') if f.endswith('.wav')]
test_wav_list = [os.path.join('test_classification_wav', f) for f in os.listdir('test_classification_wav') if f.endswith('.wav')]

train_mfccs_dict = extract_mfccs(train_wav_list)

# %%
test_wav_list = [os.path.join('splitted_inter_testing', f) for f in os.listdir('splitted_inter_testing') if f.endswith('.wav')]
test_mfccs_dict = extract_mfccs(test_wav_list)

# %%
print(len(train_mfccs_dict))
len(test_mfccs_dict)
# Out:
# 6656
# 1429

# %%
# calculate the mean of the mfccs and the stddev for each wav file and save it to a numpy array
def get_mfccs_stats(mfccs_dict):
    mfccs_stats = []
    for wav_file, mfccs in mfccs_dict.items():
        mfccs_stats.append({
            'wav_file': wav_file,
            'mfccs_mean': mfccs.mean(axis=1),
            'mfccs_stddev': mfccs.std(axis=1)
        })
    return mfccs_stats

train_mfccs_stats = get_mfccs_stats(train_mfccs_dict)
test_mfccs_stats = get_mfccs_stats(test_mfccs_dict)
# convert the list of dictionaries to a DataFrame
train_mfccs_stats_df = pd.DataFrame(train_mfccs_stats)
train_mfccs_stats_df.set_index('wav_file', inplace=True)
# create separate columns for each MFCC
train_mfccs_stats_df = pd.concat([train_mfccs_stats_df.drop(['mfccs_mean', 'mfccs_stddev'], axis=1),
                                  train_mfccs_stats_df['mfccs_mean'].apply(pd.Series).add_prefix('mfccs_mean_'),
                                  train_mfccs_stats_df['mfccs_stddev'].apply(pd.Series).add_prefix('mfccs_stddev_')],
                                 axis=1)

train_mfccs_stats_df
test_mfccs_stats_df = pd.DataFrame(test_mfccs_stats)
test_mfccs_stats = get_mfccs_stats(test_mfccs_dict)
test_mfccs_stats_df.set_index('wav_file', inplace=True)
# create separate columns for each MFCC
test_mfccs_stats_df = pd.concat([test_mfccs_stats_df.drop(['mfccs_mean', 'mfccs_stddev'], axis=1),
                                  test_mfccs_stats_df['mfccs_mean'].apply(pd.Series).add_prefix('mfccs_mean_'),
                                  test_mfccs_stats_df['mfccs_stddev'].apply(pd.Series).add_prefix('mfccs_stddev_')],
                                 axis=1)

test_mfccs_stats_df

# add a column for the label
train_mfccs_stats_df['label'] = train_mfccs_stats_df.index.str.split('_').str[-1].str.split('.').str[0]
train_mfccs_stats_df

# # convert the first column of the dataframes to have only the label,which is the last word of the file name
# train_mfccs_stats_df.index = train_mfccs_stats_df.index.str.split('_').str[-1].str.split('.').str[0]
# # rename the column to label from wav_file
# train_mfccs_stats_df.index.name = 'label'
# test_mfccs_stats_df.index = test_mfccs_stats_df.index.str.split('_').str[-1].str.split('.').str[0]
# test_mfccs_stats_df.index.name = 'label'
# train_mfccs_stats_df
# Out:
#                                                     mfccs_mean_0  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...   -457.997467
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...   -509.067810
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...   -569.072754
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...   -504.975922
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...   -600.645325
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...   -558.230774
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...   -601.828674
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...   -491.445648
# splitted_training/64727249_7.1_1_p1_105_seg1_No...   -606.948303
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...   -540.965210
#
#                                                     mfccs_mean_1  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...    213.167435
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...    218.815643
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...    187.846756
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...    193.575638
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...    208.621384
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...    205.445663
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...    226.140213
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...    263.389893
# splitted_training/64727249_7.1_1_p1_105_seg1_No...    211.462402
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...    207.350296
#
#                                                     mfccs_mean_2  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...     83.412956
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...     64.833534
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...     93.511215
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...     72.182053
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...     81.831795
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...     89.144798
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...     72.007957
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...     71.919334
# splitted_training/64727249_7.1_1_p1_105_seg1_No...     95.737877
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...     78.461693
#
#                                                     mfccs_mean_3  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...      4.431201
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...    -22.786715
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...     24.347721
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...      0.667532
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...     -5.644009
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...     16.067612
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...    -15.530037
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...    -38.951969
# splitted_training/64727249_7.1_1_p1_105_seg1_No...     11.062070
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...     -5.984053
#
#                                                     mfccs_mean_4  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...    -17.138275
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...    -32.501263
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...    -11.183994
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...    -16.468887
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...    -37.072651
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...    -11.971696
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...    -17.882122
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...    -43.607185
# splitted_training/64727249_7.1_1_p1_105_seg1_No...    -22.475885
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...    -24.043436
#
#                                                     mfccs_mean_5  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...    -10.074658
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...     -8.034741
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...    -12.672734
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...     -7.206603
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...    -26.529625
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...    -13.987014
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...      2.902568
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...    -14.222660
# splitted_training/64727249_7.1_1_p1_105_seg1_No...    -15.475955
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...     -8.710640
#
#                                                     mfccs_mean_6  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...     -5.471889
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...      2.702834
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...     -6.614258
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...     -3.106101
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...    -10.099458
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...    -11.575561
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...     -0.390579
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...     -6.761450
# splitted_training/64727249_7.1_1_p1_105_seg1_No...     -3.013548
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...     -0.234625
#
#                                                     mfccs_mean_7  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...     -8.064613
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...      0.605102
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...     -6.549531
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...     -4.665320
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...     -3.277571
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...     -7.590700
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...     -8.634903
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...    -13.972475
# splitted_training/64727249_7.1_1_p1_105_seg1_No...     -0.904237
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...     -3.491806
#
#                                                     mfccs_mean_8  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...     -8.776545
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...     -4.676734
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...     -8.923048
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...     -7.777528
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...     -7.870863
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...     -4.901174
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...    -13.330599
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...    -17.128479
# splitted_training/64727249_7.1_1_p1_105_seg1_No...     -9.925117
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...     -9.621945
#
#                                                     mfccs_mean_9  ...  \
# wav_file                                                          ...
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...     -5.561886  ...
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...     -7.568634  ...
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...    -10.004530  ...
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...     -5.703880  ...
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...    -10.431726  ...
# ...                                                          ...  ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...
# splitted_inter_testing/40890405_3.3_0_p3_3660_s...         2.127307
# splitted_inter_testing/65049153_0.8_0_p3_3761_s...         1.366743
# splitted_inter_testing/65049153_0.8_0_p2_3770_s...         1.079826
# ...                                                             ...
# splitted_inter_testing/41225759_7.2_1_p4_4220_s...         1.199157
# splitted_inter_testing/63902360_5.5_0_p3_3512_s...         4.284266
# splitted_inter_testing/65118898_0.7_0_p2_4161_s...         1.584130
# splitted_inter_testing/40890405_3.3_0_p4_3679_s...         1.879206
# splitted_inter_testing/65109516_0.2_0_p4_3657_s...         1.800593
#
#                                                     mfccs_stddev_12  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...         2.309266
# splitted_inter_testing/41223618_1.0_0_p4_3615_s...         4.747894
# splitted_inter_testing/40890405_3.3_0_p3_3660_s...         1.487266
# splitted_inter_testing/65049153_0.8_0_p3_3761_s...         2.618812
# splitted_inter_testing/65049153_0.8_0_p2_3770_s...         0.461779
# ...                                                             ...
# splitted_inter_testing/41225759_7.2_1_p4_4220_s...         2.670312
# splitted_inter_testing/63902360_5.5_0_p3_3512_s...         0.521609
# splitted_inter_testing/65118898_0.7_0_p2_4161_s...         3.029173
# splitted_inter_testing/40890405_3.3_0_p4_3679_s...         2.944812
# splitted_inter_testing/65109516_0.2_0_p4_3657_s...         0.717917
#
#                                                            label
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...        Normal
# splitted_inter_testing/41223618_1.0_0_p4_3615_s...        Normal
# splitted_inter_testing/40890405_3.3_0_p3_3660_s...        Normal
# splitted_inter_testing/65049153_0.8_0_p3_3761_s...  Fine Crackle
# splitted_inter_testing/65049153_0.8_0_p2_3770_s...        Normal
# ...                                                          ...
# splitted_inter_testing/41225759_7.2_1_p4_4220_s...        Normal
# splitted_inter_testing/63902360_5.5_0_p3_3512_s...        Normal
# splitted_inter_testing/65118898_0.7_0_p2_4161_s...        Wheeze
# splitted_inter_testing/40890405_3.3_0_p4_3679_s...        Normal
# splitted_inter_testing/65109516_0.2_0_p4_3657_s...        Normal
#
# [1429 rows x 27 columns]

# %%
# find the the instances of a specific name from the wav file column
def find_instances(df, name):
    return df[df.index.str.contains(name)]

find_instances(test_mfccs_stats_df, 'splitted_inter_testing/64585803_5.8_0_p3_3692_seg1_Normal.wav')
# Out:
#                                                     mfccs_mean_0  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...   -446.588715
#
#                                                     mfccs_mean_1  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...    220.567825
#
#                                                     mfccs_mean_2  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...     74.083641
#
#                                                     mfccs_mean_3  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...    -10.361392
#
#                                                     mfccs_mean_4  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...    -19.758821
#
#                                                     mfccs_mean_5  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...     -1.511281
#
#                                                     mfccs_mean_6  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...      2.670626
#
#                                                     mfccs_mean_7  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...      -3.97762
#
#                                                     mfccs_mean_8  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...     -8.053535
#
#                                                     mfccs_mean_9  ...  \
# wav_file                                                          ...
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...     -9.877378  ...
#
#                                                     mfccs_stddev_4  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...        2.928602
#
#                                                     mfccs_stddev_5  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...        3.714105
#
#                                                     mfccs_stddev_6  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...         3.49788
#
#                                                     mfccs_stddev_7  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...        5.357415
#
#                                                     mfccs_stddev_8  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...        4.427191
#
#                                                     mfccs_stddev_9  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...        2.592401
#
#                                                     mfccs_stddev_10  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...         1.269221
#
#                                                     mfccs_stddev_11  \
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...         1.478379
#
#                                                     mfccs_stddev_12   label
# wav_file
# splitted_inter_testing/64585803_5.8_0_p3_3692_s...         1.988212  Normal
#
# [1 rows x 27 columns]

# %%
#  Can you make a proccess that checks the dataframe and in the name of the file it has the seg section, i want a column named group that for all files with the same recording number, the group is the same
def add_group_column(df):
    df['group'] = df.index.str.split('_').str[-3]
    return df

train_mfccs_stats_df = add_group_column(train_mfccs_stats_df)
test_mfccs_stats_df = add_group_column(test_mfccs_stats_df)

train_mfccs_stats_df
# Out:
#                                                     mfccs_mean_0  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...   -457.997467
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...   -509.067810
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...   -569.072754
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...   -504.975922
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...   -600.645325
# ...                                                          ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...   -558.230774
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...   -601.828674
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...   -491.445648
# splitted_training/64727249_7.1_1_p1_105_seg1_No...   -606.948303
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...   -540.965210
#
#                                                     mfccs_mean_1  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N
...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...         0.865321
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...         3.726453
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...         4.029910
# splitted_training/64727249_7.1_1_p1_105_seg1_No...         0.749147
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...         1.518193
#
#                                                     mfccs_stddev_11  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...         0.931060
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...         2.640931
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...         2.833020
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...         1.488339
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...         1.318144
# ...                                                             ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...         1.282879
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...         5.277624
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...         4.035165
# splitted_training/64727249_7.1_1_p1_105_seg1_No...         1.559106
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...         1.787856
#
#                                                     mfccs_stddev_12  \
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...         1.455228
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...         1.870206
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...         0.990349
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...         1.419768
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...         0.934701
# ...                                                             ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...         1.781661
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...         3.785033
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...         3.898819
# splitted_training/64727249_7.1_1_p1_105_seg1_No...         1.261001
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...         1.536089
#
#                                                              label  group
# wav_file
# splitted_training/64618861_9.0_0_p3_2621_seg3_N...          Normal   2621
# splitted_training/65099422_0.5_0_p1_2541_seg6_N...          Normal   2541
# splitted_training/42272778_7.5_0_p4_1292_seg3_N...          Normal   1292
# splitted_training/65045423_5.2_1_p2_2769_seg2_N...          Normal   2769
# splitted_training/65097128_5.6_1_p1_2539_seg7_N...          Normal   2539
# ...                                                            ...    ...
# splitted_training/64552260_3.3_1_p4_2216_seg1_N...          Normal   2216
# splitted_training/65091224_2.9_0_p4_3330_seg5_N...          Normal   3330
# splitted_training/64960343_1.3_0_p3_579_seg5_Wh...  Wheeze+Crackle    579
# splitted_training/64727249_7.1_1_p1_105_seg1_No...          Normal    105
# splitted_training/41246720_4.2_0_p3_1969_seg4_N...          Normal   1969
#
# [6656 rows x 28 columns]

# %%
# count the number of instances of each label
print(train_mfccs_stats_df['label'].value_counts())
# drop from training the Rhonchi and Stridor instances
train_mfccs_stats_df = train_mfccs_stats_df.drop(train_mfccs_stats_df[train_mfccs_stats_df['label']=='Rhonchi'].index)
train_mfccs_stats_df = train_mfccs_stats_df.drop(train_mfccs_stats_df[train_mfccs_stats_df['label']=='Stridor'].index)
print(train_mfccs_stats_df['label'].value_counts())
# Out:
# label
# Normal            5159
# Fine Crackle       912
# Wheeze             452
# Coarse Crackle      49
# Rhonchi             39
# Wheeze+Crackle      30
# Stridor             15
# Name: count, dtype: int64
# label
# Normal            5159
# Fine Crackle       912
# Wheeze             452
# Coarse Crackle      49
# Wheeze+Crackle      30
# Name: count, dtype: int64

# %%
print(test_mfccs_stats_df['label'].value_counts())
# Out:
# label
# Normal            1040
# Wheeze             305
# Fine Crackle        80
# Coarse Crackle       3
# Wheeze+Crackle       1
# Name: count, dtype: int64

# %%
# convert the label column from string to one hot encoding
# train_mfccs_stats_df = pd.get_dummies(train_mfccs_stats_df, columns=['label'], prefix='label')
# train_mfccs_stats_df

# %%
# test_mfccs_stats_df = pd.get_dummies(test_mfccs_stats_df, columns=['label'], prefix='label')
# test_mfccs_stats_df

# %%
# find all rows with group column equal to something
# def find_group(df, group):
#     return df[df['group'] == group]

# find_group(test_mfccs_stats_df, '3692')

# %%
# save both dataframes to csv files
train_mfccs_stats_df.to_csv('train_mfccs_stats.csv')
test_mfccs_stats_df.to_csv('test_mfccs_stats.csv')
